# %%
import turicreate as tc

# %%
sf = tc.SFrame('datasets_828921_1417131_Space_Corrected.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1e9d2be709f2> in <module>
# ----> 1 sf = tc.SFrame('datasets_828921_1417131_Space_Corrected.csv')
#
# NameError: name 'tc' is not defined

# %%
sf
# Out:
# Columns:
# 	X1	int
# 	Unnamed: 0	int
# 	Company Name	str
# 	Location	str
# 	Datum	str
# 	Detail	str
# 	Status Rocket	str
# 	Rocket	float
# 	Status Mission	str
#
# Rows: 4324
#
# Data:
# +----+------------+--------------+-------------------------------+
# | X1 | Unnamed: 0 | Company Name |            Location           |
# +----+------------+--------------+-------------------------------+
# | 0  |     0      |    SpaceX    | LC-39A, Kennedy Space Cent... |
# | 1  |     1      |     CASC     | Site 9401 (SLS-2), Jiuquan... |
# | 2  |     2      |    SpaceX    | Pad A, Boca Chica, Texas, USA |
# | 3  |     3      |  Roscosmos   | Site 200/39, Baikonur Cosm... |
# | 4  |     4      |     ULA      | SLC-41, Cape Canaveral AFS... |
# | 5  |     5      |     CASC     | LC-9, Taiyuan Satellite La... |
# | 6  |     6      |  Roscosmos   | Site 31/6, Baikonur Cosmod... |
# | 7  |     7      |     CASC     | LC-101, Wenchang Satellite... |
# ...

# %%
sf.show()
# Out:
# Materializing SFrame
# ...

# %%
sf.head()
# Out:
# Columns:
# 	X1	int
# 	Unnamed: 0	int
# 	Company Name	str
# 	Location	str
# 	Datum	str
# 	Detail	str
# 	Status Rocket	str
# 	Rocket	float
# 	Status Mission	str
#
# Rows: 10
#
# Data:
# +----+------------+--------------+-------------------------------+
# | X1 | Unnamed: 0 | Company Name |            Location           |
# +----+------------+--------------+-------------------------------+
# | 0  |     0      |    SpaceX    | LC-39A, Kennedy Space Cent... |
# | 1  |     1      |     CASC     | Site 9401 (SLS-2), Jiuquan... |
# | 2  |     2      |    SpaceX    | Pad A, Boca Chica, Texas, USA |
# | 3  |     3      |  Roscosmos   | Site 200/39, Baikonur Cosm... |
# | 4  |     4      |     ULA      | SLC-41, Cape Canaveral AFS... |
# | 5  |     5      |     CASC     | LC-9, Taiyuan Satellite La... |
# | 6  |     6      |  Roscosmos   | Site 31/6, Baikonur Cosmod... |
# | 7  |     7      |     CASC     | LC-101, Wenchang Satellite... |
# ...

# %%
sf['Status Mission'].show()
# Out:
# Materializing SArray
# ...
